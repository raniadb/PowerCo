# %%
#import os
#os.environ["PATH"]

# %%
FILES_PATH = 'Files'
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
training_hist_data = pd.read_csv('files/ml_case_training_hist_data.csv',parse_dates=['price_date'],index_col='id')
training_hist_data.head()
# Out:
#                                  price_date  price_p1_var  price_p2_var  \
# id
# 038af19179925da21a25619c5a24b745 2015-01-01      0.151367           0.0
# 038af19179925da21a25619c5a24b745 2015-02-01      0.151367           0.0
# 038af19179925da21a25619c5a24b745 2015-03-01      0.151367           0.0
# 038af19179925da21a25619c5a24b745 2015-04-01      0.149626           0.0
# 038af19179925da21a25619c5a24b745 2015-05-01      0.149626           0.0
#
#                                   price_p3_var  price_p1_fix  price_p2_fix  \
# id
# 038af19179925da21a25619c5a24b745           0.0     44.266931           0.0
# 038af19179925da21a25619c5a24b745           0.0     44.266931           0.0
# 038af19179925da21a25619c5a24b745           0.0     44.266931           0.0
# 038af19179925da21a25619c5a24b745           0.0     44.266931           0.0
# 038af19179925da21a25619c5a24b745           0.0     44.266931           0.0
#
#                                   price_p3_fix
# id
# 038af19179925da21a25619c5a24b745           0.0
# 038af19179925da21a25619c5a24b745           0.0
# 038af19179925da21a25619c5a24b745           0.0
# 038af19179925da21a25619c5a24b745           0.0
# 038af19179925da21a25619c5a24b745           0.0

# %%
training_hist_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 193002 entries, 038af19179925da21a25619c5a24b745 to 16f51cdc2baa19af0b940ee1b3dd17d5
# Data columns (total 7 columns):
# price_date      193002 non-null datetime64[ns]
# price_p1_var    191643 non-null float64
# price_p2_var    191643 non-null float64
# price_p3_var    191643 non-null float64
# price_p1_fix    191643 non-null float64
# price_p2_fix    191643 non-null float64
# price_p3_fix    191643 non-null float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 11.8+ MB

# %%
test_hist_data = pd.read_csv('files/ml_case_test_hist_data.csv',parse_dates=['price_date'],index_col='id')
test_hist_data.head()
# Out:
#                                  price_date  price_p1_var  price_p2_var  \
# id
# 3acc714fbd9b3ccaac3c412cf220e929 2015-01-01      0.168185      0.084213
# 3acc714fbd9b3ccaac3c412cf220e929 2015-02-01      0.168185      0.084213
# 3acc714fbd9b3ccaac3c412cf220e929 2015-03-01      0.168185      0.084213
# 3acc714fbd9b3ccaac3c412cf220e929 2015-04-01      0.168185      0.084213
# 3acc714fbd9b3ccaac3c412cf220e929 2015-05-01      0.168185      0.084213
#
#                                   price_p3_var  price_p1_fix  price_p2_fix  \
# id
# 3acc714fbd9b3ccaac3c412cf220e929           0.0     44.266931           0.0
# 3acc714fbd9b3ccaac3c412cf220e929           0.0     44.266931           0.0
# 3acc714fbd9b3ccaac3c412cf220e929           0.0     44.266931           0.0
# 3acc714fbd9b3ccaac3c412cf220e929           0.0     44.266931           0.0
# 3acc714fbd9b3ccaac3c412cf220e929           0.0     44.266930           0.0
#
#                                   price_p3_fix
# id
# 3acc714fbd9b3ccaac3c412cf220e929           0.0
# 3acc714fbd9b3ccaac3c412cf220e929           0.0
# 3acc714fbd9b3ccaac3c412cf220e929           0.0
# 3acc714fbd9b3ccaac3c412cf220e929           0.0
# 3acc714fbd9b3ccaac3c412cf220e929           0.0

# %%
test_hist_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 48236 entries, 3acc714fbd9b3ccaac3c412cf220e929 to d0c4087eda93c5ceaa52de5aacd0d688
# Data columns (total 7 columns):
# price_date      48236 non-null datetime64[ns]
# price_p1_var    47934 non-null float64
# price_p2_var    47934 non-null float64
# price_p3_var    47934 non-null float64
# price_p1_fix    47934 non-null float64
# price_p2_fix    47934 non-null float64
# price_p3_fix    47934 non-null float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 2.9+ MB

# %%
hist_data = training_hist_data.append(test_hist_data)
hist_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 241238 entries, 038af19179925da21a25619c5a24b745 to d0c4087eda93c5ceaa52de5aacd0d688
# Data columns (total 7 columns):
# price_date      241238 non-null datetime64[ns]
# price_p1_var    239577 non-null float64
# price_p2_var    239577 non-null float64
# price_p3_var    239577 non-null float64
# price_p1_fix    239577 non-null float64
# price_p2_fix    239577 non-null float64
# price_p3_fix    239577 non-null float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 14.7+ MB

# %%
hist_data = hist_data.replace(0,np.NaN)
hist_data = hist_data.dropna(how='any',axis=0)
hist_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100029 entries, 31f2ce549924679a3cbb2d128ae9ea43 to d0c4087eda93c5ceaa52de5aacd0d688
# Data columns (total 7 columns):
# price_date      100029 non-null datetime64[ns]
# price_p1_var    100029 non-null float64
# price_p2_var    100029 non-null float64
# price_p3_var    100029 non-null float64
# price_p1_fix    100029 non-null float64
# price_p2_fix    100029 non-null float64
# price_p3_fix    100029 non-null float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 6.1+ MB

# %%
hist_data['price_month'] = hist_data['price_date'].dt.strftime('%Y-%m')
hist_data.head()
# Out:
#                                  price_date  price_p1_var  price_p2_var  \
# id
# 31f2ce549924679a3cbb2d128ae9ea43 2015-01-01      0.125976      0.103395
# 31f2ce549924679a3cbb2d128ae9ea43 2015-02-01      0.125976      0.103395
# 31f2ce549924679a3cbb2d128ae9ea43 2015-03-01      0.125976      0.103395
# 31f2ce549924679a3cbb2d128ae9ea43 2015-04-01      0.125976      0.103395
# 31f2ce549924679a3cbb2d128ae9ea43 2015-05-01      0.124815      0.102234
#
#                                   price_p3_var  price_p1_fix  price_p2_fix  \
# id
# 31f2ce549924679a3cbb2d128ae9ea43      0.071536     40.565969     24.339581
# 31f2ce549924679a3cbb2d128ae9ea43      0.071536     40.565969     24.339581
# 31f2ce549924679a3cbb2d128ae9ea43      0.071536     40.565969     24.339581
# 31f2ce549924679a3cbb2d128ae9ea43      0.071536     40.565969     24.339581
# 31f2ce549924679a3cbb2d128ae9ea43      0.070375     40.565969     24.339581
#
#                                   price_p3_fix price_month
# id
# 31f2ce549924679a3cbb2d128ae9ea43     16.226389     2015-01
# 31f2ce549924679a3cbb2d128ae9ea43     16.226389     2015-02
# 31f2ce549924679a3cbb2d128ae9ea43     16.226389     2015-03
# 31f2ce549924679a3cbb2d128ae9ea43     16.226389     2015-04
# 31f2ce549924679a3cbb2d128ae9ea43     16.226389     2015-05

# %%
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(12,10))
hist_data.groupby('price_month')['price_p1_fix'].mean().plot(ax=axes[0,0])
hist_data.groupby('price_month')['price_p1_var'].mean().plot(ax=axes[0,1])
hist_data.groupby('price_month')['price_p2_fix'].mean().plot(ax=axes[1,0])
hist_data.groupby('price_month')['price_p2_var'].mean().plot(ax=axes[1,1])
hist_data.groupby('price_month')['price_p3_fix'].mean().plot(ax=axes[2,0])
hist_data.groupby('price_month')['price_p3_var'].mean().plot(ax=axes[2,1])

# %%
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(12,10))
hist_data.boxplot(vert=False,ax=axes[0,0],column='price_p1_fix',by='price_month')
hist_data.boxplot(vert=False,ax=axes[0,1],column='price_p1_var',by='price_month')
hist_data.boxplot(vert=False,ax=axes[1,0],column='price_p2_fix',by='price_month')
hist_data.boxplot(vert=False,ax=axes[1,1],column='price_p2_var',by='price_month')
hist_data.boxplot(vert=False,ax=axes[2,0],column='price_p3_fix',by='price_month')
hist_data.boxplot(vert=False,ax=axes[2,1],column='price_p3_var',by='price_month')

# %%
training_data = pd.read_csv('files/ml_case_training_data.csv',
                            parse_dates=['date_activ','date_end','date_first_activ','date_modif_prod','date_renewal'],
                            index_col='id')
test_data = pd.read_csv('files/ml_case_test_data.csv',
                        parse_dates=['date_activ','date_end','date_first_activ','date_modif_prod','date_renewal'],
                        index_col='id')
all_data = training_data.append(test_data)
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20120 entries, 48ada52261e7cf58715202705a0451c9 to 9d04b44f8d8be096420da85198b5d1e3
# Data columns (total 31 columns):
# activity_new                8221 non-null object
# campaign_disc_ele           0 non-null float64
# channel_sales               14846 non-null object
# cons_12m                    20120 non-null int64
# cons_gas_12m                20120 non-null int64
# cons_last_month             20120 non-null int64
# date_activ                  20120 non-null datetime64[ns]
# date_end                    20118 non-null datetime64[ns]
# date_first_activ            4385 non-null datetime64[ns]
# date_modif_prod             19918 non-null datetime64[ns]
# date_renewal                20076 non-null datetime64[ns]
# forecast_base_bill_ele      4385 non-null float64
# forecast_base_bill_year     4385 non-null float64
# forecast_bill_12m           4385 non-null float64
# forecast_cons               4385 non-null float64
# forecast_cons_12m           20120 non-null float64
# forecast_cons_year          20120 non-null int64
# forecast_discount_energy    19970 non-null float64
# forecast_meter_rent_12m     20120 non-null float64
# forecast_price_energy_p1    19970 non-null float64
# forecast_price_energy_p2    19970 non-null float64
# forecast_price_pow_p1       19970 non-null float64
# has_gas                     20120 non-null object
# imp_cons                    20120 non-null float64
# margin_gross_pow_ele        20105 non-null float64
# margin_net_pow_ele          20105 non-null float64
# nb_prod_act                 20120 non-null int64
# net_margin                  20102 non-null float64
# num_years_antig             20120 non-null int64
# origin_up                   20006 non-null object
# pow_max                     20116 non-null float64
# dtypes: datetime64[ns](5), float64(16), int64(6), object(4)
# memory usage: 4.9+ MB

# %%
import pandas_profiling
pandas_profiling.ProfileReport(all_data)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas_profiling\plot.py:15: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "C:\ProgramData\Anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\ProgramData\Anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2808, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-16e3f59bba3c>", line 5, in <module>
#     get_ipython().magic('matplotlib inline')
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2146, in magic
#     return self.run_line_magic(magic_name, magic_arg_s)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2067, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-108>", line 2, in matplotlib
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magics\pylab.py", line 99, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2930, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py", line 307, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py", line 229, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py", line 1305, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "C:\ProgramData\Anaconda3\lib\importlib\__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\__init__.py", line 14, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use(BACKEND)
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>32 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>20120 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>13.3% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>4.9 MiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>256.0 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>15 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>4 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>5 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>1 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>7 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_activity_new"><code>activity_new</code></a> has 11899 / 59.1% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_activity_new"><code>activity_new</code></a> has a high cardinality: 445 distinct values  <span class="label label-warning">Warning</span></li><li><a href="#pp_var_campaign_disc_ele"><code>campaign_disc_ele</code></a> has 20120 / 100.0% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_campaign_disc_ele"><code>campaign_disc_ele</code></a> has constant value  <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_channel_sales"><code>channel_sales</code></a> has 5274 / 26.2% missing values <span class="label label-default">Missing</span></li><li><a href="#pp_var_cons_gas_12m"><code>cons_gas_12m</code></a> has 16476 / 81.9% zeros <span class="label label-info">Zeros</span></li><li><a href="#pp_var_cons_last_month"><code>cons_last_month</code></a> is highly correlated with <a href="#pp_var_cons_12m"><code>cons_12m</code></a> (ρ = 0.92736) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_date_first_activ"><code>date_first_activ</code></a> has 15735 / 78.2% missing

# %%
all_data['margin_net_pow_ele'].describe()
# Out:
# count    20105.000000
# mean        21.353071
# std         28.838847
# min       -981.560000
# 25%         11.950000
# 50%         21.000000
# 75%         29.500000
# max        500.320000
# Name: margin_net_pow_ele, dtype: float64

# %%
all_data['margin_net_pow_ele'].hist(bins=50,range=(-100,100))

# %%
import datetime
date1 = datetime.datetime.strptime('01/01/16', "%m/%d/%y").date()
training_data['days_renewal'] = (date1-training_data['date_renewal']).dt.days
training_data[['date_renewal','days_renewal']].head()
# Out:
#                                  date_renewal  days_renewal
# id
# 48ada52261e7cf58715202705a0451c9   2015-11-09          53.0
# 24011ae4ebbe3035111d65fa7c15bc57   2015-06-23         192.0
# d29c2c54acc38ff3c0614d0a653813dd   2015-08-31         123.0
# 764c75f661154dac3a6c254cd082ea7d   2015-04-17         259.0
# bba03439a292a1e166f80264c16191cb   2015-03-31         276.0

# %%
training_data['days_end'] = (date1-training_data['date_end']).dt.days
training_data['days_activ'] = (date1-training_data['date_activ']).dt.days
training_data['days_modif_prod'] = (date1-training_data['date_modif_prod']).dt.days

# %%
training_output = pd.read_csv('files/ml_case_training_output.csv',index_col='id')
training_output.head()
# Out:
#                                   churn
# id
# 48ada52261e7cf58715202705a0451c9      0
# 24011ae4ebbe3035111d65fa7c15bc57      1
# d29c2c54acc38ff3c0614d0a653813dd      0
# 764c75f661154dac3a6c254cd082ea7d      0
# bba03439a292a1e166f80264c16191cb      0

# %%
training = pd.merge(training_data,training_output,left_index=True,right_index=True,how='inner')
training.head()
# Out:
#                                                       activity_new  \
# id
# 48ada52261e7cf58715202705a0451c9  esoiiifxdlbkcsluxmfuacbdckommixw
# 24011ae4ebbe3035111d65fa7c15bc57                               NaN
# d29c2c54acc38ff3c0614d0a653813dd                               NaN
# 764c75f661154dac3a6c254cd082ea7d                               NaN
# bba03439a292a1e166f80264c16191cb                               NaN
#
#                                   campaign_disc_ele  \
# id
# 48ada52261e7cf58715202705a0451c9                NaN
# 24011ae4ebbe3035111d65fa7c15bc57                NaN
# d29c2c54acc38ff3c0614d0a653813dd                NaN
# 764c75f661154dac3a6c254cd082ea7d                NaN
# bba03439a292a1e166f80264c16191cb                NaN
#
#                                                      channel_sales  cons_12m  \
# id
# 48ada52261e7cf58715202705a0451c9  lmkebamcaaclubfxadlmueccxoimlema    309275
# 24011ae4ebbe3035111d65fa7c15bc57  foosdfpfkusacimwkcsosbicdxkicaua         0
# d29c2c54acc38ff3c0614d0a653813dd                               NaN      4660
# 764c75f661154dac3a6c254cd082ea7d  foosdfpfkusacimwkcsosbicdxkicaua       544
# bba03439a292a1e166f80264c16191cb  lmkebamcaaclubfxadlmueccxoimlema      1584
#
#                                   cons_gas_12m  cons_last_month date_activ  \
# id
# 48ada52261e7cf58715202705a0451c9             0            10025 2012-11-07
# 24011ae4ebbe3035111d65fa7c15bc57         54946                0 2013-06-15
# d29c2c54acc38ff3c0614d0a653813dd             0                0 2009-08-21
# 764c75f661154dac3a6c254cd082ea7d             0                0 2010-04-16
# bba03439a292a1e166f80264c16191cb             0                0 2010-03-30
#
#                                    date_end date_first_activ date_modif_prod  \
# id
# 48ada52261e7cf58715202705a0451c9 2016-11-06              NaT      2012-11-07
# 24011ae4ebbe3035111d65fa7c15bc57 2016-06-15              NaT             NaT
# d29c2c54acc38ff3c0614d0a653813dd 2016-08-30              NaT      2009-08-21
# 764c75f661154dac3a6c254cd082ea7d 2016-04-16              NaT      2010-04-16
# bba03439a292a1e166f80264c16191cb 2016-03-30              NaT      2010-03-30
#
#                                   ...   nb_prod_act  net_margin  \
# id                                ...
# 48ada52261e7cf58715202705a0451c9  ...             1     1732.36
# 24011ae4ebbe3035111d65fa7c15bc57  ...             2      678.99
# d29c2c54acc38ff3c0614d0a653813dd  ...             1       18.89
# 764c75f661154dac3a6c254cd082ea7d  ...             1        6.60
# bba03439a292a1e166f80264c16191cb  ...             1       25.46
#
#                                   num_years_antig  \
# id
# 48ada52261e7cf58715202705a0451c9                3
# 24011ae4ebbe3035111d65fa7c15bc57                3
# d29c2c54acc38ff3c0614d0a653813dd                6
# 764c75f661154dac3a6c254cd082ea7d                6
# bba03439a292a1e166f80264c16191cb                6
#
#                                                          origin_up  pow_max  \
# id
# 48ada52261e7cf58715202705a0451c9  ldkssxwpmemidmecebumciepifcamkci  180.000
# 24011ae4ebbe3035111d65fa7c15bc57  lxidpiddsbxsbosboudacockeimpuepw   43.648
# d29c2c54acc38ff3c0614d0a653813dd  kamkkxfxxuwbdslkwifmmcsiusiuosws   13.800
# 764c75f661154dac3a6c254cd082ea7d  kamkkxfxxuwbdslkwifmmcsiusiuosws   13.856
# bba03439a292a1e166f80264c16191cb  kamkkxfxxuwbdslkwifmmcsiusiuosws   13.200
#
#                                   days_renewal  days_end  days_activ  \
# id
# 48ada52261e7cf58715202705a0451c9          53.0    -310.0        1150
# 24011ae4ebbe3035111d65fa7c15bc57         192.0    -166.0         930
# d29c2c54acc38ff3c0614d0a653813dd         123.0    -242.0        2324
# 764c75f661154dac3a6c254cd082ea7d         259.0    -106.0        2086
# bba03439a292a1e166f80264c16191cb         276.0     -89.0        2103
#
#                                   days_modif_prod  churn
# id
# 48ada52261e7cf58715202705a0451c9           1150.0      0
# 24011ae4ebbe3035111d65fa7c15bc57              NaN      1
# d29c2c54acc38ff3c0614d0a653813dd           2324.0      0
# 764c75f661154dac3a6c254cd082ea7d           2086.0      0
# bba03439a292a1e166f80264c16191cb           2103.0      0
#
# [5 rows x 36 columns]

# %%
ax = plt.subplot()
ax.figsize=(10,6)
training.plot.hexbin(x='margin_net_pow_ele',y='days_renewal',C='churn',reduce_C_function=np.sum,ax=ax,edgecolors='r',vmin=0,vmax=30,colormap='Greens')
ax.set_xlim(-600,400)
ax.set_ylim(-50,400)
# Out:
# (-50, 400)

# %%
df=training.loc[(training['days_end']<365)&(training['days_end']>-365*2),['margin_net_pow_ele','days_end','churn']].dropna()
df.head()
df.plot.hexbin(x='margin_net_pow_ele',y='days_end',C='churn',reduce_C_function=np.sum,color='orange',gridsize=100,figsize=(17,10))

# %%
training_hist_data['price_date'] = training_hist_data['price_date'].dt.strftime('%Y-%m')
training_hist_data.head()
# Out:
#                                  price_date  price_p1_var  price_p2_var  \
# id
# 038af19179925da21a25619c5a24b745    2015-01      0.151367           0.0
# 038af19179925da21a25619c5a24b745    2015-02      0.151367           0.0
# 038af19179925da21a25619c5a24b745    2015-03      0.151367           0.0
# 038af19179925da21a25619c5a24b745    2015-04      0.149626           0.0
# 038af19179925da21a25619c5a24b745    2015-05      0.149626           0.0
#
#                                   price_p3_var  price_p1_fix  price_p2_fix  \
# id
# 038af19179925da21a25619c5a24b745           0.0     44.266931           0.0
# 038af19179925da21a25619c5a24b745           0.0     44.266931           0.0
# 038af19179925da21a25619c5a24b745           0.0     44.266931           0.0
# 038af19179925da21a25619c5a24b745           0.0     44.266931           0.0
# 038af19179925da21a25619c5a24b745           0.0     44.266931           0.0
#
#                                   price_p3_fix
# id
# 038af19179925da21a25619c5a24b745           0.0
# 038af19179925da21a25619c5a24b745           0.0
# 038af19179925da21a25619c5a24b745           0.0
# 038af19179925da21a25619c5a24b745           0.0
# 038af19179925da21a25619c5a24b745           0.0

# %%
df=training_hist_data.pivot(columns='price_date')

# %%
df.head()
# Out:
#                                  price_p1_var                                \
# price_date                            2015-01   2015-02   2015-03   2015-04
# id
# 0002203ffbb812588b632b9e628cc38d     0.126098  0.126098  0.128067  0.128067
# 0004351ebdd665e6ee664792efc4fd13     0.148047  0.148047  0.148047  0.148047
# 0010bcc39e42b3c2131ed2ce55246e3c     0.150837  0.150837  0.153048  0.153048
# 0010ee3855fdea87602a5b7aba8e42de     0.123086  0.123086  0.123086  0.123086
# 00114d74e963e47177db89bc70108537     0.149434  0.149434  0.149434  0.149902
#
#                                                                           \
# price_date                         2015-05   2015-06   2015-07   2015-08
# id
# 0002203ffbb812588b632b9e628cc38d  0.128067  0.128067  0.128067  0.119906
# 0004351ebdd665e6ee664792efc4fd13  0.148405  0.148405  0.148405  0.143943
# 0010bcc39e42b3c2131ed2ce55246e3c  0.153048  0.205742  0.205742  0.201280
# 0010ee3855fdea87602a5b7aba8e42de  0.123086  0.123086  0.121229  0.113068
# 00114d74e963e47177db89bc70108537  0.149902  0.149902  0.149902  0.145440
#
#                                                         ...     price_p3_fix  \
# price_date                         2015-09   2015-10    ...          2015-03
# id                                                      ...
# 0002203ffbb812588b632b9e628cc38d  0.119906  0.119906    ...        16.291555
# 0004351ebdd665e6ee664792efc4fd13  0.143943  0.143943    ...         0.000000
# 0010bcc39e42b3c2131ed2ce55246e3c  0.201280  0.201280    ...         0.000000
# 0010ee3855fdea87602a5b7aba8e42de  0.113068  0.113068    ...        16.226389
# 00114d74e963e47177db89bc70108537  0.145440  0.145440    ...         0.000000
#
#                                                                               \
# price_date                          2015-04    2015-05    2015-06    2015-07
# id
# 0002203ffbb812588b632b9e628cc38d  16.291555  16.291555  16.291555  16.291555
# 0004351ebdd665e6ee664792efc4fd13   0.000000   0.000000   0.000000   0.000000
# 0010bcc39e42b3c2131ed2ce55246e3c   0.000000   0.000000   0.000000   0.000000
# 0010ee3855fdea87602a5b7aba8e42de  16.226389  16.226389  16.226383  16.291555
# 00114d74e963e47177db89bc70108537   0.000000   0.000000   0.000000   0.000000
#
#                                                                               \
# price_date                          2015-08    2015-09    2015-10    2015-11
# id
# 0002203ffbb812588b632b9e628cc38d  16.291555  16.291555  16.291555  16.291555
# 0004351ebdd665e6ee664792efc4fd13   0.000000   0.000000   0.000000   0.000000
# 0010bcc39e42b3c2131ed2ce55246e3c   0.000000   0.000000   0.000000   0.000000
# 0010ee3855fdea87602a5b7aba8e42de  16.291555  16.291555  16.291555  16.291555
# 00114d74e963e47177db89bc70108537   0.000000   0.000000   0.000000   0.000000
#
#
# price_date                          2015-12
# id
# 0002203ffbb812588b632b9e628cc38d  16.291555
# 0004351ebdd665e6ee664792efc4fd13   0.000000
# 0010bcc39e42b3c2131ed2ce55246e3c   0.000000
# 0010ee3855fdea87602a5b7aba8e42de  16.291555
# 00114d74e963e47177db89bc70108537   0.000000
#
# [5 rows x 72 columns]

# %%
df['price_p1_var'].head()
# Out:
# price_date                         2015-01   2015-02   2015-03   2015-04  \
# id
# 0002203ffbb812588b632b9e628cc38d  0.126098  0.126098  0.128067  0.128067
# 0004351ebdd665e6ee664792efc4fd13  0.148047  0.148047  0.148047  0.148047
# 0010bcc39e42b3c2131ed2ce55246e3c  0.150837  0.150837  0.153048  0.153048
# 0010ee3855fdea87602a5b7aba8e42de  0.123086  0.123086  0.123086  0.123086
# 00114d74e963e47177db89bc70108537  0.149434  0.149434  0.149434  0.149902
#
# price_date                         2015-05   2015-06   2015-07   2015-08  \
# id
# 0002203ffbb812588b632b9e628cc38d  0.128067  0.128067  0.128067  0.119906
# 0004351ebdd665e6ee664792efc4fd13  0.148405  0.148405  0.148405  0.143943
# 0010bcc39e42b3c2131ed2ce55246e3c  0.153048  0.205742  0.205742  0.201280
# 0010ee3855fdea87602a5b7aba8e42de  0.123086  0.123086  0.121229  0.113068
# 00114d74e963e47177db89bc70108537  0.149902  0.149902  0.149902  0.145440
#
# price_date                         2015-09   2015-10   2015-11   2015-12
# id
# 0002203ffbb812588b632b9e628cc38d  0.119906  0.119906  0.119906  0.119906
# 0004351ebdd665e6ee664792efc4fd13  0.143943  0.143943  0.143943  0.143943
# 0010bcc39e42b3c2131ed2ce55246e3c  0.201280  0.201280  0.201280  0.201280
# 0010ee3855fdea87602a5b7aba8e42de  0.113068  0.113068  0.113068  0.113068
# 00114d74e963e47177db89bc70108537  0.145440  0.145440  0.145440  0.145440

# %%
df.columns[0]
# Out:
# ('price_p1_var', '2015-01')

# %%
df.columns=[df.columns[i][0]+'_'+df.columns[i][1] for i in range(6*12)]

# %%
df.head()
# Out:
#                                   price_p1_var_2015-01  price_p1_var_2015-02  \
# id
# 0002203ffbb812588b632b9e628cc38d              0.126098              0.126098
# 0004351ebdd665e6ee664792efc4fd13              0.148047              0.148047
# 0010bcc39e42b3c2131ed2ce55246e3c              0.150837              0.150837
# 0010ee3855fdea87602a5b7aba8e42de              0.123086              0.123086
# 00114d74e963e47177db89bc70108537              0.149434              0.149434
#
#                                   price_p1_var_2015-03  price_p1_var_2015-04  \
# id
# 0002203ffbb812588b632b9e628cc38d              0.128067              0.128067
# 0004351ebdd665e6ee664792efc4fd13              0.148047              0.148047
# 0010bcc39e42b3c2131ed2ce55246e3c              0.153048              0.153048
# 0010ee3855fdea87602a5b7aba8e42de              0.123086              0.123086
# 00114d74e963e47177db89bc70108537              0.149434              0.149902
#
#                                   price_p1_var_2015-05  price_p1_var_2015-06  \
# id
# 0002203ffbb812588b632b9e628cc38d              0.128067              0.128067
# 0004351ebdd665e6ee664792efc4fd13              0.148405              0.148405
# 0010bcc39e42b3c2131ed2ce55246e3c              0.153048              0.205742
# 0010ee3855fdea87602a5b7aba8e42de              0.123086              0.123086
# 00114d74e963e47177db89bc70108537              0.149902              0.149902
#
#                                   price_p1_var_2015-07  price_p1_var_2015-08  \
# id
# 0002203ffbb812588b632b9e628cc38d              0.128067              0.119906
# 0004351ebdd665e6ee664792efc4fd13              0.148405              0.143943
# 0010bcc39e42b3c2131ed2ce55246e3c              0.205742              0.201280
# 0010ee3855fdea87602a5b7aba8e42de              0.121229              0.113068
# 00114d74e963e47177db89bc70108537              0.149902              0.145440
#
#                                   price_p1_var_2015-09  price_p1_var_2015-10  \
# id
# 0002203ffbb812588b632b9e628cc38d              0.119906              0.119906
# 0004351ebdd665e6ee664792efc4fd13              0.143943              0.143943
# 0010bcc39e42b3c2131ed2ce55246e3c              0.201280              0.201280
# 0010ee3855fdea87602a5b7aba8e42de              0.113068              0.113068
# 00114d74e963e47177db89bc70108537              0.145440              0.145440
#
#                                           ...           price_p3_fix_2015-03  \
# id                                        ...
# 0002203ffbb812588b632b9e628cc38d          ...                      16.291555
# 0004351ebdd665e6ee664792efc4fd13          ...                       0.000000
# 0010bcc39e42b3c2131ed2ce55246e3c          ...                       0.000000
# 0010ee3855fdea87602a5b7aba8e42de          ...                      16.226389
# 00114d74e963e47177db89bc70108537          ...                       0.000000
#
#                                   price_p3_fix_2015-04  price_p3_fix_2015-05  \
# id
# 0002203ffbb812588b632b9e628cc38d             16.291555             16.291555
# 0004351ebdd665e6ee664792efc4fd13              0.000000              0.000000
# 0010bcc39e42b3c2131ed2ce55246e3c              0.000000              0.000000
# 0010ee3855fdea87602a5b7aba8e42de             16.226389             16.226389
# 00114d74e963e47177db89bc70108537              0.000000              0.000000
#
#                                   price_p3_fix_2015-06  price_p3_fix_2015-07  \
# id
# 0002203ffbb812588b632b9e628cc38d             16.291555             16.291555
# 0004351ebdd665e6ee664792efc4fd13              0.000000              0.000000
# 0010bcc39e42b3c2131ed2ce55246e3c              0.000000              0.000000
# 0010ee3855fdea87602a5b7aba8e42de             16.226383             16.291555
# 00114d74e963e47177db89bc70108537              0.000000              0.000000
#
#                                   price_p3_fix_2015-08  price_p3_fix_2015-09  \
# id
# 0002203ffbb812588b632b9e628cc38d             16.291555             16.291555
# 0004351ebdd665e6ee664792efc4fd13              0.000000              0.000000
# 0010bcc39e42b3c2131ed2ce55246e3c              0.000000              0.000000
# 0010ee3855fdea87602a5b7aba8e42de             16.291555             16.291555
# 00114d74e963e47177db89bc70108537              0.000000              0.000000
#
#                                   price_p3_fix_2015-10  price_p3_fix_2015-11  \
# id
# 0002203ffbb812588b632b9e628cc38d             16.291555             16.291555
# 0004351ebdd665e6ee664792efc4fd13              0.000000              0.000000
# 0010bcc39e42b3c2131ed2ce55246e3c              0.000000              0.000000
# 0010ee3855fdea87602a5b7aba8e42de             16.291555             16.291555
# 00114d74e963e47177db89bc70108537              0.000000              0.000000
#
#                                   price_p3_fix_2015-12
# id
# 0002203ffbb812588b632b9e628cc38d             16.291555
# 0004351ebdd665e6ee664792efc4fd13              0.000000
# 0010bcc39e42b3c2131ed2ce55246e3c              0.000000
# 0010ee3855fdea87602a5b7aba8e42de             16.291555
# 00114d74e963e47177db89bc70108537              0.000000
#
# [5 rows x 72 columns]

# %%
df.describe()
# Out:
#        price_p1_var_2015-01  price_p1_var_2015-02  price_p1_var_2015-03  \
# count          16035.000000          16032.000000          16005.000000
# mean               0.142561              0.142757              0.143091
# std                0.022872              0.023439              0.023827
# min                0.000000              0.000000              0.000000
# 25%                0.127566              0.127566              0.127566
# 50%                0.148825              0.148825              0.148825
# 75%                0.152445              0.152445              0.152445
# max                0.280700              0.280700              0.280700
#
#        price_p1_var_2015-04  price_p1_var_2015-05  price_p1_var_2015-06  \
# count          15819.000000          15937.000000          15815.000000
# mean               0.143213              0.143512              0.143692
# std                0.024383              0.024484              0.024681
# min                0.000000              0.000000              0.000000
# 25%                0.127566              0.127566              0.127566
# 50%                0.148825              0.148825              0.148825
# 75%                0.152445              0.152445              0.152445
# max                0.280700              0.280700              0.280700
#
#        price_p1_var_2015-07  price_p1_var_2015-08  price_p1_var_2015-09  \
# count          16000.000000          16039.000000          15993.000000
# mean               0.143669              0.137905              0.137888
# std                0.024796              0.025724              0.026230
# min                0.000000              0.000000              0.000000
# 25%                0.127559              0.119389              0.119336
# 50%                0.148825              0.144524              0.144524
# 75%                0.152445              0.147983              0.147983
# max                0.280700              0.276238              0.276238
#
#        price_p1_var_2015-10          ...           price_p3_fix_2015-03  \
# count          15977.000000          ...                   16005.000000
# mean               0.137844          ...                       6.457830
# std                0.026395          ...                       7.775113
# min                0.000000          ...                      -0.065166
# 25%                0.118851          ...                       0.000000
# 50%                0.144292          ...                       0.000000
# 75%                0.147983          ...                      16.226389
# max                0.276238          ...                      16.791555
#
#        price_p3_fix_2015-04  price_p3_fix_2015-05  price_p3_fix_2015-06  \
# count          15819.000000          15937.000000          15815.000000
# mean               6.528723              6.448145              6.388537
# std                7.788008              7.774088              7.766004
# min               -0.065166             -0.065166             -0.065172
# 25%                0.000000              0.000000              0.000000
# 50%                0.000000              0.000000              0.000000
# 75%               16.226389             16.226389             16.226383
# max               16.791555             16.791555             16.791555
#
#        price_p3_fix_2015-07  price_p3_fix_2015-08  price_p3_fix_2015-09  \
# count          16000.000000          16039.000000          15993.000000
# mean               6.457581              6.453573              6.427358
# std                7.782627              7.783394              7.779913
# min               -0.065172              0.000000              0.000000
# 25%                0.000000              0.000000              0.000000
# 50%                0.000000              0.000000              0.000000
# 75%               16.226383             16.226383             16.291555
# max               16.791555             16.791555             16.791555
#
#        price_p3_fix_2015-10  price_p3_fix_2015-11  price_p3_fix_2015-12
# count          15977.000000          16029.000000          15962.000000
# mean               6.439320              6.444858              6.480254
# std                7.786581              7.795539              7.809667
# min                0.000000              0.000000              0.000000
# 25%                0.000000              0.000000              0.000000
# 50%                0.000000              0.000000              0.000000
# 75%               16.291555             16.291555             16.291555
# max               16.958222             17.291555             17.458221
#
# [8 rows x 72 columns]

# %%
dftrain = pd.merge(training_data,df,how='inner',left_index=True,right_index=True)
dftrain.columns
# Out:
# Index(['activity_new', 'campaign_disc_ele', 'channel_sales', 'cons_12m',
#        'cons_gas_12m', 'cons_last_month', 'date_activ', 'date_end',
#        'date_first_activ', 'date_modif_prod',
#        ...
#        'price_p3_fix_2015-03', 'price_p3_fix_2015-04', 'price_p3_fix_2015-05',
#        'price_p3_fix_2015-06', 'price_p3_fix_2015-07', 'price_p3_fix_2015-08',
#        'price_p3_fix_2015-09', 'price_p3_fix_2015-10', 'price_p3_fix_2015-11',
#        'price_p3_fix_2015-12'],
#       dtype='object', length=107)

# %%
cols = [c for c in dftrain.columns if (c.lower()[:8] != 'forecast') & (c.lower() != 'campaign_disc_ele') & (c.lower() != 'date_first_activ')]
dftrain = dftrain[cols]

# %%
dftrain.columns
# Out:
# Index(['activity_new', 'channel_sales', 'cons_12m', 'cons_gas_12m',
#        'cons_last_month', 'date_activ', 'date_end', 'date_modif_prod',
#        'date_renewal', 'has_gas', 'imp_cons', 'margin_gross_pow_ele',
#        'margin_net_pow_ele', 'nb_prod_act', 'net_margin', 'num_years_antig',
#        'origin_up', 'pow_max', 'days_renewal', 'days_end', 'days_activ',
#        'days_modif_prod', 'price_p1_var_2015-01', 'price_p1_var_2015-02',
#        'price_p1_var_2015-03', 'price_p1_var_2015-04', 'price_p1_var_2015-05',
#        'price_p1_var_2015-06', 'price_p1_var_2015-07', 'price_p1_var_2015-08',
#        'price_p1_var_2015-09', 'price_p1_var_2015-10', 'price_p1_var_2015-11',
#        'price_p1_var_2015-12', 'price_p2_var_2015-01', 'price_p2_var_2015-02',
#        'price_p2_var_2015-03', 'price_p2_var_2015-04', 'price_p2_var_2015-05',
#        'price_p2_var_2015-06', 'price_p2_var_2015-07', 'price_p2_var_2015-08',
#        'price_p2_var_2015-09', 'price_p2_var_2015-10', 'price_p2_var_2015-11',
#        'price_p2_var_2015-12', 'price_p3_var_2015-01', 'price_p3_var_2015-02',
#        'price_p3_var_2015-03', 'price_p3_var_2015-04', 'price_p3_var_2015-05',
#        'price_p3_var_2015-06', 'price_p3_var_2015-07', 'price_p3_var_2015-08',
#        'price_p3_var_2015-09', 'price_p3_var_2015-10', 'price_p3_var_2015-11',
#        'price_p3_var_2015-12', 'price_p1_fix_2015-01', 'price_p1_fix_2015-02',
#        'price_p1_fix_2015-03', 'price_p1_fix_2015-04', 'price_p1_fix_2015-05',
#        'price_p1_fix_2015-06', 'price_p1_fix_2015-07', 'price_p1_fix_2015-08',
#        'price_p1_fix_2015-09', 'price_p1_fix_2015-10', 'price_p1_fix_2015-11',
#        'price_p1_fix_2015-12', 'price_p2_fix_2015-01', 'price_p2_fix_2015-02',
#        'price_p2_fix_2015-03', 'price_p2_fix_2015-04', 'price_p2_fix_2015-05',
#        'price_p2_fix_2015-06', 'price_p2_fix_2015-07', 'price_p2_fix_2015-08',
#        'price_p2_fix_2015-09', 'price_p2_fix_2015-10', 'price_p2_fix_2015-11',
#        'price_p2_fix_2015-12', 'price_p3_fix_2015-01', 'price_p3_fix_2015-02',
#        'price_p3_fix_2015-03', 'price_p3_fix_2015-04', 'price_p3_fix_2015-05',
#        'price_p3_fix_2015-06', 'price_p3_fix_2015-07', 'price_p3_fix_2015-08',
#        'price_p3_fix_2015-09', 'price_p3_fix_2015-10', 'price_p3_fix_2015-11',
#        'price_p3_fix_2015-12'],
#       dtype='object')

# %%
dftrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16096 entries, 48ada52261e7cf58715202705a0451c9 to 563dde550fd624d7352f3de77c0cdfcd
# Data columns (total 94 columns):
# activity_new            6551 non-null object
# channel_sales           11878 non-null object
# cons_12m                16096 non-null int64
# cons_gas_12m            16096 non-null int64
# cons_last_month         16096 non-null int64
# date_activ              16096 non-null datetime64[ns]
# date_end                16094 non-null datetime64[ns]
# date_modif_prod         15939 non-null datetime64[ns]
# date_renewal            16056 non-null datetime64[ns]
# has_gas                 16096 non-null object
# imp_cons                16096 non-null float64
# margin_gross_pow_ele    16083 non-null float64
# margin_net_pow_ele      16083 non-null float64
# nb_prod_act             16096 non-null int64
# net_margin              16081 non-null float64
# num_years_antig         16096 non-null int64
# origin_up               16009 non-null object
# pow_max                 16093 non-null float64
# days_renewal            16056 non-null float64
# days_end                16094 non-null float64
# days_activ              16096 non-null int64
# days_modif_prod         15939 non-null float64
# price_p1_var_2015-01    16035 non-null float64
# price_p1_var_2015-02    16032 non-null float64
# price_p1_var_2015-03    16005 non-null float64
# price_p1_var_2015-04    15819 non-null float64
# price_p1_var_2015-05    15937 non-null float64
# price_p1_var_2015-06    15815 non-null float64
# price_p1_var_2015-07    16000 non-null float64
# price_p1_var_2015-08    16039 non-null float64
# price_p1_var_2015-09    15993 non-null float64
# price_p1_var_2015-10    15977 non-null float64
# price_p1_var_2015-11    16029 non-null float64
# price_p1_var_2015-12    15962 non-null float64
# price_p2_var_2015-01    16035 non-null float64
# price_p2_var_2015-02    16032 non-null float64
# price_p2_var_2015-03    16005 non-null float64
# price_p2_var_2015-04    15819 non-null float64
# price_p2_var_2015-05    15937 non-null float64
# price_p2_var_2015-06    15815 non-null float64
# price_p2_var_2015-07    16000 non-null float64
# price_p2_var_2015-08    16039 non-null float64
# price_p2_var_2015-09    15993 non-null float64
# price_p2_var_2015-10    15977 non-null float64
# price_p2_var_2015-11    16029 non-null float64
# price_p2_var_2015-12    15962 non-null float64
# price_p3_var_2015-01    16035 non-null float64
# price_p3_var_2015-02    16032 non-null float64
# price_p3_var_2015-03    16005 non-null float64
# price_p3_var_2015-04    15819 non-null float64
# price_p3_var_2015-05    15937 non-null float64
# price_p3_var_2015-06    15815 non-null float64
# price_p3_var_2015-07    16000 non-null float64
# price_p3_var_2015-08    16039 non-null float64
# price_p3_var_2015-09    15993 non-null float64
# price_p3_var_2015-10    15977 non-null float64
# price_p3_var_2015-11    16029 non-null float64
# price_p3_var_2015-12    15962 non-null float64
# price_p1_fix_2015-01    16035 non-null float64
# price_p1_fix_2015-02    16032 non-null float64
# price_p1_fix_2015-03    16005 non-null float64
# price_p1_fix_2015-04    15819 non-null float64
# price_p1_fix_2015-05    15937 non-null float64
# price_p1_fix_2015-06    15815 non-null float64
# price_p1_fix_2015-07    16000 non-null float64
# price_p1_fix_2015-08    16039 non-null float64
# price_p1_fix_2015-09    15993 non-null float64
# price_p1_fix_2015-10    15977 non-null float64
# price_p1_fix_2015-11    16029 non-null float64
# price_p1_fix_2015-12    15962 non-null float64
# price_p2_fix_2015-01    16035 non-null float64
# price_p2_fix_2015-02    16032 non-null float64
# price_p2_fix_2015-03    16005 non-null float64
# price_p2_fix_2015-04    15819 non-null float64
# price_p2_fix_2015-05    15937 non-null float64
# price_p2_fix_2015-06    15815 non-null float64
# price_p2_fix_2015-07    16000 non-null float64
# price_p2_fix_2015-08    16039 non-null float64
# price_p2_fix_2015-09    15993 non-null float64
# price_p2_fix_2015-10    15977 non-null float64
# price_p2_fix_2015-11    16029 non-null float64
# price_p2_fix_2015-12    15962 non-null float64
# price_p3_fix_2015-01    16035 non-null float64
# price_p3_fix_2015-02    16032 non-null float64
# price_p3_fix_2015-03    16005 non-null float64
# price_p3_fix_2015-04    15819 non-null float64
# price_p3_fix_2015-05    15937 non-null float64
# price_p3_fix_2015-06    15815 non-null float64
# price_p3_fix_2015-07    16000 non-null float64
# price_p3_fix_2015-08    16039 non-null float64
# price_p3_fix_2015-09    15993 non-null float64
# price_p3_fix_2015-10    15977 non-null float64
# price_p3_fix_2015-11    16029 non-null float64
# price_p3_fix_2015-12    15962 non-null float64
# dtypes: datetime64[ns](4), float64(80), int64(6), object(4)
# memory usage: 11.7+ MB

# %%
dftrain_nums = dftrain.select_dtypes(include=['float64','int64'])

# %%
dftrain_nums_mean = dftrain_nums.replace(0,np.NaN)

# %%
from sklearn.preprocessing import Imputer
imp = Imputer(axis=0, missing_values='NaN', strategy='mean')
imp.fit_transform(dftrain_nums_mean)
dftrain_nums_mean = pd.DataFrame(imp.fit_transform(dftrain_nums_mean),index=dftrain_nums.index)
dftrain_nums_mean.columns = dftrain_nums.columns

# %%
dftrain_objs = dftrain.select_dtypes(include=['object'])
dftrain_objs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16096 entries, 48ada52261e7cf58715202705a0451c9 to 563dde550fd624d7352f3de77c0cdfcd
# Data columns (total 4 columns):
# activity_new     6551 non-null object
# channel_sales    11878 non-null object
# has_gas          16096 non-null object
# origin_up        16009 non-null object
# dtypes: object(4)
# memory usage: 628.8+ KB

# %%
dftrain_objs['channel_sales'].value_counts()
# Out:
# foosdfpfkusacimwkcsosbicdxkicaua    7377
# lmkebamcaaclubfxadlmueccxoimlema    2073
# usilxuppasemubllopkaafesmlibmsdf    1444
# ewpakwlliwisiwduibdlfmalxowmwpci     966
# sddiedcslfslkckwlfkdpoeeailfpeds      12
# epumfxlbckeskwekxbiuasklxalciiuu       4
# fixdbufsefwooaasfcxdxadsiekoceaa       2
# Name: channel_sales, dtype: int64

# %%
dftrain_objs_most = dftrain_objs.apply(lambda x:x.fillna(x.value_counts().index[0]))

# %%
dftrain_objs_most['channel_sales'].value_counts()
# Out:
# foosdfpfkusacimwkcsosbicdxkicaua    11595
# lmkebamcaaclubfxadlmueccxoimlema     2073
# usilxuppasemubllopkaafesmlibmsdf     1444
# ewpakwlliwisiwduibdlfmalxowmwpci      966
# sddiedcslfslkckwlfkdpoeeailfpeds       12
# epumfxlbckeskwekxbiuasklxalciiuu        4
# fixdbufsefwooaasfcxdxadsiekoceaa        2
# Name: channel_sales, dtype: int64

# %%
dftrain_dats = dftrain.select_dtypes(include=['datetime'])
dftrain_dats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16096 entries, 48ada52261e7cf58715202705a0451c9 to 563dde550fd624d7352f3de77c0cdfcd
# Data columns (total 4 columns):
# date_activ         16096 non-null datetime64[ns]
# date_end           16094 non-null datetime64[ns]
# date_modif_prod    15939 non-null datetime64[ns]
# date_renewal       16056 non-null datetime64[ns]
# dtypes: datetime64[ns](4)
# memory usage: 628.8+ KB

# %%
#DECISION TREE
dftrain_nums_mean['churn'] = training['churn']

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=100)
for train_index, test_index in split.split(dftrain_nums_mean, dftrain_nums_mean['churn']):
    train_set = dftrain_nums_mean.iloc[train_index]
    test_set = dftrain_nums_mean.iloc[test_index]
X_train = train_set.loc[:, train_set.columns != 'churn']
y_train = train_set.iloc[:,-1]
X_test = test_set.loc[:, test_set.columns != 'churn']
y_test = test_set.iloc[:,-1]

# %%
from sklearn.tree import DecisionTreeClassifier
tree_op=DecisionTreeClassifier(random_state=100,max_depth=4)
tree_fit=tree_op.fit(X_train,y_train)
#Prediction class
y_score=tree_fit.predict(X_test)
#Look at results table
tree_cross=pd.crosstab(index=y_test,columns=y_score)
tree_cross
# Out:
# col_0     0  1
# churn
# 0      2900  1
# 1       316  3

# %%
#from scipy.stats import itemfreq
y_proba=tree_fit.predict_proba(X_test)
#itemfreq(y_proba)

# %%
tree_fit.score(X_test,y_test)
# Out:
# 0.9015527950310559

# %%
#tree_fit.tree_.threshold

# %%
from sklearn.metrics import precision_score
precision = precision_score(y_test, y_score)
print('Precision: {0:0.2f}'.format(precision))
# Out:
# Precision: 0.75

# %%
from sklearn.metrics import classification_report
target_names = ['class 0', 'class 1']
print(classification_report(y_test, y_score, target_names=target_names))
# Out:
#              precision    recall  f1-score   support
#
#     class 0       0.90      1.00      0.95      2901
#     class 1       0.75      0.01      0.02       319
#
# avg / total       0.89      0.90      0.86      3220

# %%
import graphviz
from sklearn.tree import export_graphviz
dot_data = export_graphviz(tree_fit, out_file=None, feature_names=X_train.columns) 
graph = graphviz.Source(dot_data)
graph

# %%
import pydot
graph = pydot.graph_from_dot_data(dot_data)
graph[0].write_png('tree.png')

# %%
df1 = pd.DataFrame(y_test.values,columns=['test'])
df1['proba0'] = y_proba[:,0]
df1['proba1'] = y_proba[:,1]
df1['score'] = y_score
df1_sorted = df1.sort_values('proba1',ascending = False)
df1_sorted.head()
# Out:
#       test  proba0  proba1  score
# 399      0    0.00    1.00      1
# 30       1    0.00    1.00      1
# 2104     1    0.25    0.75      1
# 1787     1    0.25    0.75      1
# 1222     0    0.50    0.50      0

# %%
df1_sorted['pred'] = -1
df1_sorted.head()
# Out:
#       test  proba0  proba1  score  pred
# 399      0    0.00    1.00      1    -1
# 30       1    0.00    1.00      1    -1
# 2104     1    0.25    0.75      1    -1
# 1787     1    0.25    0.75      1    -1
# 1222     0    0.50    0.50      0    -1

# %%
df1_sorted.iloc[:92,-1] = 1
df1_sorted.iloc[92:,-1] = 0
df1_sorted.iloc[:100,:]
# Out:
#       test    proba0    proba1  score  pred
# 399      0  0.000000  1.000000      1     1
# 30       1  0.000000  1.000000      1     1
# 2104     1  0.250000  0.750000      1     1
# 1787     1  0.250000  0.750000      1     1
# 1222     0  0.500000  0.500000      0     1
# 1822     0  0.500000  0.500000      0     1
# 1608     0  0.700495  0.299505      0     1
# 733      1  0.700495  0.299505      0     1
# 1352     0  0.700495  0.299505      0     1
# 2247     0  0.700495  0.299505      0     1
# 142      0  0.700495  0.299505      0     1
# 143      0  0.700495  0.299505      0     1
# 3077     0  0.700495  0.299505      0     1
# 1255     0  0.700495  0.299505      0     1
# 1236     0  0.700495  0.299505      0     1
# 2717     1  0.700495  0.299505      0     1
# 2488     1  0.700495  0.299505      0     1
# 2699     0  0.700495  0.299505      0     1
# 844      0  0.700495  0.299505      0     1
# 268      0  0.700495  0.299505      0     1
# 1043     0  0.700495  0.299505      0     1
# 1501     0  0.700495  0.299505      0     1
# 1363     0  0.700495  0.299505      0     1
# 2511     0  0.700495  0.299505      0     1
# 147      0  0.700495  0.299505      0     1
# 964      0  0.700495  0.299505      0     1
# 507      0  0.700495  0.299505      0     1
# 254      0  0.700495  0.299505      0     1
# 1604     1  0.700495  0.299505      0     1
# 1021     0  0.700495  0.299505      0     1
# ...    ...       ...       ...    ...   ...
# 579      0  0.700495  0.299505      0     1
# 2016     0  0.700495  0.299505      0     1
# 2121     1  0.700495  0.299505      0     1
# 2546     1  0.700495  0.299505      0     1
# 1785     1  0.700495  0.299505      0     1
# 1650     0  0.700495  0.299505      0     1
# 2108     0  0.700495  0.299505      0     1
# 3134     0  0.700495  0.299505      0     1
# 951      0  0.700495  0.299505      0     1
# 2405     0  0.700495  0.299505      0     1
# 2673     0  0.700495  0.299505      0     1
# 2670     1  0.700495  0.299505      0     1
# 2151     0  0.700495  0.299505      0     1
# 1963     1  0.700495  0.299505      0     1
# 675      1  0.700495  0.299505      0     1
# 1747     1  0.700495  0.299505      0     1
# 2536     1  0.700495  0.299505      0     1
# 1749     0  0.700495  0.299505      0     1
# 1968     0  0.700495  0.299505      0     1
# 528      0  0.700495  0.299505      0     1
# 2004     0  0.700495  0.299505      0     1
# 662      0  0.800000  0.200000      0     1
# 928      0  0.805285  0.194715      0     0
# 1977     0  0.805285  0.194715      0     0
# 2426     1  0.805285  0.194715      0     0
# 1926     0  0.805285  0.194715      0     0
# 1432     0  0.805285  0.194715      0     0
# 1495     1  0.805285  0.194715      0     0
# 1990     1  0.805285  0.194715      0     0
# 439      0  0.805285  0.194715      0     0
#
# [100 rows x 5 columns]

# %%
tree_cross=pd.crosstab(index=df1_sorted['test'],columns=df1_sorted['pred'])
tree_cross
# Out:
# pred     0   1
# test
# 0     2836  65
# 1      292  27

# %%
print(classification_report(df1_sorted['test'], df1_sorted['pred'], target_names=target_names))
# Out:
#              precision    recall  f1-score   support
#
#     class 0       0.91      0.98      0.94      2901
#     class 1       0.29      0.08      0.13       319
#
# avg / total       0.85      0.89      0.86      3220

# %%
#DECISION TREE + CATEGORICAL VARIABLES

# %%
dftrain_objs_most.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16096 entries, 48ada52261e7cf58715202705a0451c9 to 563dde550fd624d7352f3de77c0cdfcd
# Data columns (total 4 columns):
# activity_new     16096 non-null object
# channel_sales    16096 non-null object
# has_gas          16096 non-null object
# origin_up        16096 non-null object
# dtypes: object(4)
# memory usage: 628.8+ KB

# %%
dftrain_objs_most['channel_sales'].value_counts()
# Out:
# foosdfpfkusacimwkcsosbicdxkicaua    11595
# lmkebamcaaclubfxadlmueccxoimlema     2073
# usilxuppasemubllopkaafesmlibmsdf     1444
# ewpakwlliwisiwduibdlfmalxowmwpci      966
# sddiedcslfslkckwlfkdpoeeailfpeds       12
# epumfxlbckeskwekxbiuasklxalciiuu        4
# fixdbufsefwooaasfcxdxadsiekoceaa        2
# Name: channel_sales, dtype: int64

# %%
#dftrain_objs_most['channel_sales'].astype('category').cat.codes

# %%
dummies = pd.get_dummies(dftrain_objs_most[['channel_sales','has_gas','origin_up']],
                         prefix=['channel_sales','has_gas','origin_up'])

# %%
dftrain_all = (dftrain_nums_mean.loc[:,train_set.columns != 'churn']).join(dummies)

# %%
dftrain_all['churn'] = dftrain_nums_mean['churn']

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=100)
for train_index, test_index in split.split(dftrain_all, dftrain_all['churn']):
    train_set = dftrain_all.iloc[train_index]
    test_set = dftrain_all.iloc[test_index]
X_train = train_set.loc[:, train_set.columns != 'churn']
y_train = train_set.iloc[:,-1]
X_test = test_set.loc[:, test_set.columns != 'churn']
y_test = test_set.iloc[:,-1]

# %%
from sklearn.tree import DecisionTreeClassifier
tree_op=DecisionTreeClassifier(random_state=100,max_depth=4)
tree_fit=tree_op.fit(X_train,y_train)
#Prediction class
y_score=tree_fit.predict(X_test)
#Look at results table
tree_cross=pd.crosstab(index=y_test,columns=y_score)
tree_cross
# Out:
# col_0     0  1
# churn
# 0      2899  2
# 1       316  3

# %%
#from scipy.stats import itemfreq
y_proba=tree_fit.predict_proba(X_test)
#itemfreq(y_proba)

# %%
tree_fit.score(X_test,y_test)
# Out:
# 0.90124223602484477

# %%
#tree_fit.tree_.threshold

# %%
from sklearn.metrics import precision_score
precision = precision_score(y_test, y_score)
print('Precision: {0:0.2f}'.format(precision))
# Out:
# Precision: 0.60

# %%
from sklearn.metrics import classification_report
target_names = ['class 0', 'class 1']
print(classification_report(y_test, y_score, target_names=target_names))
# Out:
#              precision    recall  f1-score   support
#
#     class 0       0.90      1.00      0.95      2901
#     class 1       0.60      0.01      0.02       319
#
# avg / total       0.87      0.90      0.86      3220

# %%
#from sklearn.metrics import precision_recall_curve
#precision, recall, _ = precision_recall_curve(y_test, y_score)
#plt.step(recall, precision, color='b', alpha=0.2, where='post')
#plt.fill_between(recall, precision, step='post', alpha=0.2, color='b')
#plt.xlabel('Recall')
#plt.ylabel('Precision')
#plt.ylim([0.0, 1.05])
#plt.xlim([0.0, 1.0])
#plt.title('2-class Precision-Recall curve: AP={0:0.2f}'.format(precision))

# %%
import graphviz
from sklearn.tree import export_graphviz
dot_data = export_graphviz(tree_fit, out_file=None, feature_names=X_train.columns) 
graph = graphviz.Source(dot_data)
graph

# %%
import pydot
graph = pydot.graph_from_dot_data(dot_data)
graph[0].write_png('tree.png')

# %%
df1 = pd.DataFrame(y_test.values,columns=['test'])
df1['proba0'] = y_proba[:,0]
df1['proba1'] = y_proba[:,1]
df1['score'] = y_score
df1_sorted = df1.sort_values('proba1',ascending = False)
df1_sorted
# Out:
#       test    proba0    proba1  score
# 662      0  0.000000  1.000000      1
# 30       1  0.000000  1.000000      1
# 399      0  0.000000  1.000000      1
# 1787     1  0.250000  0.750000      1
# 2104     1  0.250000  0.750000      1
# 1822     0  0.500000  0.500000      0
# 1222     0  0.500000  0.500000      0
# 255      1  0.745763  0.254237      0
# 1608     0  0.745763  0.254237      0
# 254      0  0.745763  0.254237      0
# 1612     0  0.745763  0.254237      0
# 1650     0  0.745763  0.254237      0
# 567      1  0.745763  0.254237      0
# 1638     0  0.745763  0.254237      0
# 569      0  0.745763  0.254237      0
# 2832     0  0.745763  0.254237      0
# 268      0  0.745763  0.254237      0
# 1043     0  0.745763  0.254237      0
# 1604     1  0.745763  0.254237      0
# 270      1  0.745763  0.254237      0
# 274      0  0.745763  0.254237      0
# 1067     1  0.745763  0.254237      0
# 2347     0  0.745763  0.254237      0
# 768      0  0.745763  0.254237      0
# 2816     0  0.745763  0.254237      0
# 2777     0  0.745763  0.254237      0
# 995      0  0.745763  0.254237      0
# 1700     0  0.745763  0.254237      0
# 1697     0  0.745763  0.254237      0
# 1692     0  0.745763  0.254237      0
# ...    ...       ...       ...    ...
# 976      0  0.958121  0.041879      0
# 2454     0  0.958121  0.041879      0
# 1711     0  0.958121  0.041879      0
# 1115     0  0.958121  0.041879      0
# 171      0  0.958121  0.041879      0
# 2444     0  0.958121  0.041879      0
# 2999     0  0.958121  0.041879      0
# 2810     0  0.958121  0.041879      0
# 1514     0  0.958121  0.041879      0
# 2807     0  0.958121  0.041879      0
# 411      0  0.958121  0.041879      0
# 2804     0  0.958121  0.041879      0
# 291      0  0.958121  0.041879      0
# 154      0  0.958121  0.041879      0
# 517      0  0.958121  0.041879      0
# 2602     0  0.958121  0.041879      0
# 2800     0  0.958121  0.041879      0
# 146      0  0.958121  0.041879      0
# 2429     0  0.958121  0.041879      0
# 143      0  0.958121  0.041879      0
# 1735     1  0.958121  0.041879      0
# 2425     0  0.958121  0.041879      0
# 3023     1  0.958121  0.041879      0
# 2424     0  0.958121  0.041879      0
# 2422     1  0.958121  0.041879      0
# 1739     0  0.958121  0.041879      0
# 407      0  0.958121  0.041879      0
# 1742     0  0.958121  0.041879      0
# 1485     0  0.958121  0.041879      0
# 2274     0  0.958121  0.041879      0
#
# [3220 rows x 4 columns]

# %%
df1_sorted['pred'] = -1
df1_sorted.head()
# Out:
#       test  proba0  proba1  score  pred
# 662      0    0.00    1.00      1    -1
# 30       1    0.00    1.00      1    -1
# 399      0    0.00    1.00      1    -1
# 1787     1    0.25    0.75      1    -1
# 2104     1    0.25    0.75      1    -1

# %%
df1_sorted[df1_sorted['proba1'] >= 0.20]
# Out:
#       test    proba0    proba1  score  pred
# 662      0  0.000000  1.000000      1    -1
# 30       1  0.000000  1.000000      1    -1
# 399      0  0.000000  1.000000      1    -1
# 1787     1  0.250000  0.750000      1    -1
# 2104     1  0.250000  0.750000      1    -1
# 1822     0  0.500000  0.500000      0    -1
# 1222     0  0.500000  0.500000      0    -1
# 255      1  0.745763  0.254237      0    -1
# 1608     0  0.745763  0.254237      0    -1
# 254      0  0.745763  0.254237      0    -1
# 1612     0  0.745763  0.254237      0    -1
# 1650     0  0.745763  0.254237      0    -1
# 567      1  0.745763  0.254237      0    -1
# 1638     0  0.745763  0.254237      0    -1
# 569      0  0.745763  0.254237      0    -1
# 2832     0  0.745763  0.254237      0    -1
# 268      0  0.745763  0.254237      0    -1
# 1043     0  0.745763  0.254237      0    -1
# 1604     1  0.745763  0.254237      0    -1
# 270      1  0.745763  0.254237      0    -1
# 274      0  0.745763  0.254237      0    -1
# 1067     1  0.745763  0.254237      0    -1
# 2347     0  0.745763  0.254237      0    -1
# 768      0  0.745763  0.254237      0    -1
# 2816     0  0.745763  0.254237      0    -1
# 2777     0  0.745763  0.254237      0    -1
# 995      0  0.745763  0.254237      0    -1
# 1700     0  0.745763  0.254237      0    -1
# 1697     0  0.745763  0.254237      0    -1
# 1692     0  0.745763  0.254237      0    -1
# ...    ...       ...       ...    ...   ...
# 142      0  0.745763  0.254237      0    -1
# 1345     0  0.745763  0.254237      0    -1
# 1166     0  0.745763  0.254237      0    -1
# 3014     0  0.745763  0.254237      0    -1
# 3021     0  0.745763  0.254237      0    -1
# 1658     0  0.759690  0.240310      0    -1
# 3194     0  0.759690  0.240310      0    -1
# 3072     0  0.759690  0.240310      0    -1
# 1362     0  0.759690  0.240310      0    -1
# 2456     0  0.759690  0.240310      0    -1
# 2814     0  0.759690  0.240310      0    -1
# 1774     0  0.759690  0.240310      0    -1
# 2811     0  0.759690  0.240310      0    -1
# 2995     0  0.759690  0.240310      0    -1
# 1348     0  0.759690  0.240310      0    -1
# 807      0  0.759690  0.240310      0    -1
# 1273     0  0.759690  0.240310      0    -1
# 94       0  0.759690  0.240310      0    -1
# 333      0  0.759690  0.240310      0    -1
# 1247     0  0.759690  0.240310      0    -1
# 1395     0  0.759690  0.240310      0    -1
# 1783     0  0.759690  0.240310      0    -1
# 2665     0  0.759690  0.240310      0    -1
# 299      0  0.759690  0.240310      0    -1
# 1094     0  0.759690  0.240310      0    -1
# 2279     0  0.759690  0.240310      0    -1
# 1134     0  0.759690  0.240310      0    -1
# 2302     0  0.759690  0.240310      0    -1
# 2096     0  0.759690  0.240310      0    -1
# 2509     0  0.759690  0.240310      0    -1
#
# [272 rows x 5 columns]

# %%
df1_sorted.iloc[:272,-1] = 1
df1_sorted.iloc[272:,-1] = 0
df1_sorted.iloc[:275,:]
# Out:
#       test    proba0    proba1  score  pred
# 662      0  0.000000  1.000000      1     1
# 30       1  0.000000  1.000000      1     1
# 399      0  0.000000  1.000000      1     1
# 1787     1  0.250000  0.750000      1     1
# 2104     1  0.250000  0.750000      1     1
# 1822     0  0.500000  0.500000      0     1
# 1222     0  0.500000  0.500000      0     1
# 255      1  0.745763  0.254237      0     1
# 1608     0  0.745763  0.254237      0     1
# 254      0  0.745763  0.254237      0     1
# 1612     0  0.745763  0.254237      0     1
# 1650     0  0.745763  0.254237      0     1
# 567      1  0.745763  0.254237      0     1
# 1638     0  0.745763  0.254237      0     1
# 569      0  0.745763  0.254237      0     1
# 2832     0  0.745763  0.254237      0     1
# 268      0  0.745763  0.254237      0     1
# 1043     0  0.745763  0.254237      0     1
# 1604     1  0.745763  0.254237      0     1
# 270      1  0.745763  0.254237      0     1
# 274      0  0.745763  0.254237      0     1
# 1067     1  0.745763  0.254237      0     1
# 2347     0  0.745763  0.254237      0     1
# 768      0  0.745763  0.254237      0     1
# 2816     0  0.745763  0.254237      0     1
# 2777     0  0.745763  0.254237      0     1
# 995      0  0.745763  0.254237      0     1
# 1700     0  0.745763  0.254237      0     1
# 1697     0  0.745763  0.254237      0     1
# 1692     0  0.745763  0.254237      0     1
# ...    ...       ...       ...    ...   ...
# 3014     0  0.745763  0.254237      0     1
# 3021     0  0.745763  0.254237      0     1
# 1658     0  0.759690  0.240310      0     1
# 3194     0  0.759690  0.240310      0     1
# 3072     0  0.759690  0.240310      0     1
# 1362     0  0.759690  0.240310      0     1
# 2456     0  0.759690  0.240310      0     1
# 2814     0  0.759690  0.240310      0     1
# 1774     0  0.759690  0.240310      0     1
# 2811     0  0.759690  0.240310      0     1
# 2995     0  0.759690  0.240310      0     1
# 1348     0  0.759690  0.240310      0     1
# 807      0  0.759690  0.240310      0     1
# 1273     0  0.759690  0.240310      0     1
# 94       0  0.759690  0.240310      0     1
# 333      0  0.759690  0.240310      0     1
# 1247     0  0.759690  0.240310      0     1
# 1395     0  0.759690  0.240310      0     1
# 1783     0  0.759690  0.240310      0     1
# 2665     0  0.759690  0.240310      0     1
# 299      0  0.759690  0.240310      0     1
# 1094     0  0.759690  0.240310      0     1
# 2279     0  0.759690  0.240310      0     1
# 1134     0  0.759690  0.240310      0     1
# 2302     0  0.759690  0.240310      0     1
# 2096     0  0.759690  0.240310      0     1
# 2509     0  0.759690  0.240310      0     1
# 1409     0  0.860465  0.139535      0     0
# 1448     0  0.860465  0.139535      0     0
# 955      0  0.860465  0.139535      0     0
#
# [275 rows x 5 columns]

# %%
tree_cross=pd.crosstab(index=df1_sorted['test'],columns=df1_sorted['pred'])
tree_cross
# Out:
# pred     0    1
# test
# 0     2687  214
# 1      261   58

# %%
print(classification_report(df1_sorted['test'], df1_sorted['pred'], target_names=target_names))
# Out:
#              precision    recall  f1-score   support
#
#     class 0       0.91      0.93      0.92      2901
#     class 1       0.21      0.18      0.20       319
#
# avg / total       0.84      0.85      0.85      3220

# %%
#LOGISTIC REGRESSION
col=['z_'+X_train.columns[i] for i in range(100)]

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train_z = pd.DataFrame(sc_X.fit_transform(X_train))
X_train_z.columns=col
X_test_z = pd.DataFrame(sc_X.fit_transform(X_test))
X_test_z.columns=col

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression(random_state = 100)
logreg.fit(X_train_z, y_train)
print('Precision {:.2f}'.format(logreg.score(X_test_z, y_test)))
# Out:
# Precision 0.90

# %%
y_score=logreg.predict(X_test_z)
tree_cross=pd.crosstab(index=y_test,columns=y_score)
tree_cross
# Out:
# col_0     0  1
# churn
# 0      2897  4
# 1       319  0

# %%
y_proba=logreg.predict_proba(X_test_z)
df1 = pd.DataFrame(y_test.values,columns=['test'])
df1['proba0'] = y_proba[:,0]
df1['proba1'] = y_proba[:,1]
df1['score'] = y_score
df1_sorted = df1.sort_values('proba1',ascending = False)
df1_sorted
# Out:
#       test    proba0    proba1  score
# 2942     0  0.063710  0.936290      1
# 2304     0  0.204080  0.795920      1
# 2831     0  0.367568  0.632432      1
# 305      0  0.415659  0.584341      1
# 775      0  0.532311  0.467689      0
# 675      1  0.544357  0.455643      0
# 1558     0  0.552486  0.447514      0
# 860      0  0.558073  0.441927      0
# 1977     0  0.604536  0.395464      0
# 1301     1  0.645322  0.354678      0
# 128      0  0.670273  0.329727      0
# 391      1  0.672491  0.327509      0
# 1644     1  0.673740  0.326260      0
# 1546     0  0.682781  0.317219      0
# 2131     0  0.686524  0.313476      0
# 2473     0  0.692266  0.307734      0
# 1604     1  0.693589  0.306411      0
# 1491     0  0.697595  0.302405      0
# 3168     0  0.708995  0.291005      0
# 2389     0  0.718787  0.281213      0
# 167      1  0.721287  0.278713      0
# 575      0  0.725654  0.274346      0
# 2418     0  0.728960  0.271040      0
# 503      0  0.737075  0.262925      0
# 263      0  0.738772  0.261228      0
# 2871     1  0.740838  0.259162      0
# 2854     1  0.746151  0.253849      0
# 2286     1  0.747973  0.252027      0
# 767      1  0.749065  0.250935      0
# 1373     1  0.749834  0.250166      0
# ...    ...       ...       ...    ...
# 1769     0  0.994974  0.005026      0
# 750      0  0.995104  0.004896      0
# 3177     0  0.995134  0.004866      0
# 2002     0  0.995283  0.004717      0
# 2954     0  0.995520  0.004480      0
# 1042     0  0.995845  0.004155      0
# 2199     0  0.995960  0.004040      0
# 143      0  0.996026  0.003974      0
# 1038     0  0.996228  0.003772      0
# 977      0  0.996287  0.003713      0
# 1837     0  0.996524  0.003476      0
# 3155     0  0.996702  0.003298      0
# 870      0  0.996953  0.003047      0
# 1995     0  0.997062  0.002938      0
# 2548     0  0.997458  0.002542      0
# 2785     0  0.997607  0.002393      0
# 2595     0  0.997682  0.002318      0
# 300      0  0.997728  0.002272      0
# 815      0  0.998146  0.001854      0
# 2283     0  0.998374  0.001626      0
# 2235     0  0.998424  0.001576      0
# 2168     0  0.998433  0.001567      0
# 1490     0  0.998547  0.001453      0
# 1168     0  0.998885  0.001115      0
# 2790     0  0.999105  0.000895      0
# 2228     0  0.999214  0.000786      0
# 2487     0  0.999421  0.000579      0
# 3173     0  0.999667  0.000333      0
# 1316     0  0.999718  0.000282      0
# 1609     0  0.999734  0.000266      0
#
# [3220 rows x 4 columns]

# %%
df1_sorted['pred'] = -1
df1_sorted[df1_sorted['proba1'] >= 0.20]
# Out:
#       test    proba0    proba1  score  pred
# 2942     0  0.063710  0.936290      1    -1
# 2304     0  0.204080  0.795920      1    -1
# 2831     0  0.367568  0.632432      1    -1
# 305      0  0.415659  0.584341      1    -1
# 775      0  0.532311  0.467689      0    -1
# 675      1  0.544357  0.455643      0    -1
# 1558     0  0.552486  0.447514      0    -1
# 860      0  0.558073  0.441927      0    -1
# 1977     0  0.604536  0.395464      0    -1
# 1301     1  0.645322  0.354678      0    -1
# 128      0  0.670273  0.329727      0    -1
# 391      1  0.672491  0.327509      0    -1
# 1644     1  0.673740  0.326260      0    -1
# 1546     0  0.682781  0.317219      0    -1
# 2131     0  0.686524  0.313476      0    -1
# 2473     0  0.692266  0.307734      0    -1
# 1604     1  0.693589  0.306411      0    -1
# 1491     0  0.697595  0.302405      0    -1
# 3168     0  0.708995  0.291005      0    -1
# 2389     0  0.718787  0.281213      0    -1
# 167      1  0.721287  0.278713      0    -1
# 575      0  0.725654  0.274346      0    -1
# 2418     0  0.728960  0.271040      0    -1
# 503      0  0.737075  0.262925      0    -1
# 263      0  0.738772  0.261228      0    -1
# 2871     1  0.740838  0.259162      0    -1
# 2854     1  0.746151  0.253849      0    -1
# 2286     1  0.747973  0.252027      0    -1
# 767      1  0.749065  0.250935      0    -1
# 1373     1  0.749834  0.250166      0    -1
# ...    ...       ...       ...    ...   ...
# 1346     0  0.780771  0.219229      0    -1
# 2777     0  0.781219  0.218781      0    -1
# 1125     0  0.781295  0.218705      0    -1
# 2174     1  0.784096  0.215904      0    -1
# 1426     1  0.786742  0.213258      0    -1
# 1314     0  0.786813  0.213187      0    -1
# 3028     1  0.787331  0.212669      0    -1
# 1228     1  0.787703  0.212297      0    -1
# 2173     0  0.788175  0.211825      0    -1
# 142      0  0.788493  0.211507      0    -1
# 2891     0  0.788901  0.211099      0    -1
# 1713     0  0.789384  0.210616      0    -1
# 1681     0  0.789519  0.210481      0    -1
# 2025     0  0.790620  0.209380      0    -1
# 1306     1  0.791029  0.208971      0    -1
# 2465     0  0.791714  0.208286      0    -1
# 2826     0  0.792057  0.207943      0    -1
# 2622     0  0.793089  0.206911      0    -1
# 620      0  0.793274  0.206726      0    -1
# 2815     0  0.795251  0.204749      0    -1
# 1173     0  0.795815  0.204185      0    -1
# 2694     0  0.795955  0.204045      0    -1
# 447      0  0.796353  0.203647      0    -1
# 964      0  0.797646  0.202354      0    -1
# 1402     0  0.798047  0.201953      0    -1
# 1867     0  0.798760  0.201240      0    -1
# 24       0  0.798895  0.201105      0    -1
# 1963     1  0.799181  0.200819      0    -1
# 2317     1  0.799357  0.200643      0    -1
# 2034     1  0.799958  0.200042      0    -1
#
# [90 rows x 5 columns]

# %%
df1_sorted.iloc[:90,-1] = 1
df1_sorted.iloc[90:,-1] = 0
df1_sorted.iloc[:100,:]
# Out:
#       test    proba0    proba1  score  pred
# 2942     0  0.063710  0.936290      1     1
# 2304     0  0.204080  0.795920      1     1
# 2831     0  0.367568  0.632432      1     1
# 305      0  0.415659  0.584341      1     1
# 775      0  0.532311  0.467689      0     1
# 675      1  0.544357  0.455643      0     1
# 1558     0  0.552486  0.447514      0     1
# 860      0  0.558073  0.441927      0     1
# 1977     0  0.604536  0.395464      0     1
# 1301     1  0.645322  0.354678      0     1
# 128      0  0.670273  0.329727      0     1
# 391      1  0.672491  0.327509      0     1
# 1644     1  0.673740  0.326260      0     1
# 1546     0  0.682781  0.317219      0     1
# 2131     0  0.686524  0.313476      0     1
# 2473     0  0.692266  0.307734      0     1
# 1604     1  0.693589  0.306411      0     1
# 1491     0  0.697595  0.302405      0     1
# 3168     0  0.708995  0.291005      0     1
# 2389     0  0.718787  0.281213      0     1
# 167      1  0.721287  0.278713      0     1
# 575      0  0.725654  0.274346      0     1
# 2418     0  0.728960  0.271040      0     1
# 503      0  0.737075  0.262925      0     1
# 263      0  0.738772  0.261228      0     1
# 2871     1  0.740838  0.259162      0     1
# 2854     1  0.746151  0.253849      0     1
# 2286     1  0.747973  0.252027      0     1
# 767      1  0.749065  0.250935      0     1
# 1373     1  0.749834  0.250166      0     1
# ...    ...       ...       ...    ...   ...
# 2891     0  0.788901  0.211099      0     1
# 1713     0  0.789384  0.210616      0     1
# 1681     0  0.789519  0.210481      0     1
# 2025     0  0.790620  0.209380      0     1
# 1306     1  0.791029  0.208971      0     1
# 2465     0  0.791714  0.208286      0     1
# 2826     0  0.792057  0.207943      0     1
# 2622     0  0.793089  0.206911      0     1
# 620      0  0.793274  0.206726      0     1
# 2815     0  0.795251  0.204749      0     1
# 1173     0  0.795815  0.204185      0     1
# 2694     0  0.795955  0.204045      0     1
# 447      0  0.796353  0.203647      0     1
# 964      0  0.797646  0.202354      0     1
# 1402     0  0.798047  0.201953      0     1
# 1867     0  0.798760  0.201240      0     1
# 24       0  0.798895  0.201105      0     1
# 1963     1  0.799181  0.200819      0     1
# 2317     1  0.799357  0.200643      0     1
# 2034     1  0.799958  0.200042      0     1
# 1700     0  0.800028  0.199972      0     0
# 1960     0  0.800071  0.199929      0     0
# 395      1  0.800369  0.199631      0     0
# 1381     1  0.801591  0.198409      0     0
# 3191     0  0.801620  0.198380      0     0
# 270      1  0.801672  0.198328      0     0
# 2816     0  0.801846  0.198154      0     0
# 672      1  0.802043  0.197957      0     0
# 827      0  0.802794  0.197206      0     0
# 1573     1  0.803397  0.196603      0     0
#
# [100 rows x 5 columns]

# %%
tree_cross=pd.crosstab(index=df1_sorted['test'],columns=df1_sorted['pred'])
tree_cross
# Out:
# pred     0   1
# test
# 0     2841  60
# 1      289  30

# %%
print(classification_report(df1_sorted['test'], df1_sorted['pred'], target_names=target_names))
# Out:
#              precision    recall  f1-score   support
#
#     class 0       0.91      0.98      0.94      2901
#     class 1       0.33      0.09      0.15       319
#
# avg / total       0.85      0.89      0.86      3220

# %%
def allrows(ytest,yproba,yscore):
    df = pd.DataFrame(ytest.values,columns=['test'],index=ytest.index)
    df['proba0'] = yproba[:,0]
    df['proba1'] = yproba[:,1]
    df['forecast_bill_12m'] = training_data['forecast_bill_12m']
    df = df.dropna(how='any',axis=0)
    df = df.sort_values('proba1',ascending = False)
    return df

# %%
def firstnrows(dfall,n,redu):
    df = dfall.iloc[:n,:].copy()
    df['actual_bill_12m'] = 0
    df.loc[df['test'] == 0,'actual_bill_12m'] = df['forecast_bill_12m']*(-redu)
    df.loc[df['test'] == 1,'actual_bill_12m'] = df['forecast_bill_12m']*(1-redu)
    tot = df['actual_bill_12m'].sum()
    return df,tot

# %%
def print_threshold_precision_total(dfall,n,redu):
    df = dfall.copy()
    df['pred'] = 0
    df.iloc[:n,-1] = 1
    th=df.iloc[n-1,2]
    preci = precision_score(df['test'],df['pred'])
    df,tot = firstnrows(df,n,redu)
    return df,th,preci,tot

# %%
dfallrows = allrows(y_test,y_proba,y_score)
for i in range(1,dfallrows.shape[0]+1):
#for i in range(90,91):
    dfn,threshold,precis,total = print_threshold_precision_total(dfallrows,i,0.20)
    if total > 90000:
        print(i,'Threshold {:.5f}'.format(threshold),'Precision: {0:0.2f}'.format(precis),'Total: {0:0.5f}'.format(total))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# 120 Threshold 0.15729 Precision: 0.34 Total: 91437.92400
# 121 Threshold 0.15585 Precision: 0.35 Total: 95319.69200
# 122 Threshold 0.15564 Precision: 0.34 Total: 95049.65000
# 123 Threshold 0.15521 Precision: 0.34 Total: 93762.46600
# 124 Threshold 0.15504 Precision: 0.35 Total: 96511.34600
# 125 Threshold 0.15498 Precision: 0.34 Total: 95345.90200
# 126 Threshold 0.15495 Precision: 0.34 Total: 90099.06400

# %%
#PIPELINE
#GRIDSEARCH
#PCA
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import PCA

# %%
#pca = PCA()
scaler = StandardScaler()
logistic = LogisticRegression()
#pipe = Pipeline(steps = [('scaler', scaler), ('pca', pca), ('logistic', logistic)])
pipe = Pipeline(steps = [('scaler', scaler), ('logistic', logistic)])
#grid = GridSearchCV(pipe,dict(pca__n_components=[2, 5, 10],pca__whiten=[True],logistic__C=np.logspace(-4, 4, 5)))
#grid = GridSearchCV(pipe,dict(logistic__C=np.logspace(-4, 4, 5)))
grid = GridSearchCV(pipe,{})
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=None, error_score='raise',
#        estimator=Pipeline(memory=None,
#      steps=[('scaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('logistic', LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False))]),
#        fit_params=None, iid=True, n_jobs=1, param_grid={},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
#grid.best_estimator_.named_steps['pca']

# %%
y_score = grid.predict(X_test)
y_proba = grid.predict_proba(X_test)

# %%
pd.crosstab(index=y_test,columns=y_score)
# Out:
# col_0     0  1
# churn
# 0      2897  4
# 1       319  0

# %%
print(classification_report(y_test, y_score, target_names=target_names))
# Out:
#              precision    recall  f1-score   support
#
#     class 0       0.90      1.00      0.95      2901
#     class 1       0.00      0.00      0.00       319
#
# avg / total       0.81      0.90      0.85      3220

# %%
dfallrows = allrows(y_test,y_proba,y_score)
for i in range(1,dfallrows.shape[0]+1):
    dfn,threshold,precis,total = print_threshold_precision_total(dfallrows,i,0.20)
    if total > 90000:
        print(i,'Threshold {:.5f}'.format(threshold),'Precision: {0:0.2f}'.format(precis),'Total: {0:0.5f}'.format(total))
# Out:
# 113 Threshold 0.15899 Precision: 0.34 Total: 90524.60400
# 135 Threshold 0.15375 Precision: 0.33 Total: 92834.54000
# 136 Threshold 0.15359 Precision: 0.33 Total: 94249.37200
# 137 Threshold 0.15346 Precision: 0.33 Total: 93173.62000
# 138 Threshold 0.15331 Precision: 0.33 Total: 91886.43600
# 139 Threshold 0.15304 Precision: 0.32 Total: 91399.10600
# 140 Threshold 0.15246 Precision: 0.32 Total: 91158.89800
# 141 Threshold 0.15208 Precision: 0.32 Total: 90504.66800
# 165 Threshold 0.14880 Precision: 0.31 Total: 90502.21600

# %%
#DECISION TREE IMPORTANT FEATURES

# %%
tree_op=DecisionTreeClassifier(random_state=100)
tree_fit=tree_op.fit(X_train,y_train)
#Prediction class
y_score=tree_fit.predict(X_test)
#Look at results table
pd.crosstab(index=y_test,columns=y_score)
# Out:
# col_0     0    1
# churn
# 0      2617  284
# 1       249   70

# %%
print(classification_report(y_test, y_score, target_names=target_names))
# Out:
#              precision    recall  f1-score   support
#
#     class 0       0.92      0.90      0.91      2901
#     class 1       0.23      0.26      0.24       319
#
# avg / total       0.85      0.84      0.84      3220

# %%
imp_features = pd.DataFrame(np.column_stack([list(X_train.columns), list(tree_fit.feature_importances_)]),columns=['col','imp'])
imp_features = imp_features.sort_values('imp',ascending = False)

# %%
imp_cols = np.array('z_' + imp_features.iloc[:10,:]['col'])

# %%
X_train_z_imp = X_train_z[imp_cols]
X_test_z_imp = X_test_z[imp_cols]

# %%
logreg = LogisticRegression(random_state = 100)
logreg.fit(X_train_z_imp, y_train)
print('Precision {:.2f}'.format(logreg.score(X_test_z_imp, y_test)))
# Out:
# Precision 0.90

# %%
y_score=logreg.predict(X_test_z_imp)
pd.crosstab(index=y_test,columns=y_score)
# Out:
# col_0     0  1
# churn
# 0      2900  1
# 1       319  0

# %%
print(classification_report(y_test, y_score, target_names=target_names))
# Out:
#              precision    recall  f1-score   support
#
#     class 0       0.90      1.00      0.95      2901
#     class 1       0.00      0.00      0.00       319
#
# avg / total       0.81      0.90      0.85      3220

# %%
#HIST DATA VARIABLES / ALL CATEGORICAL RANDOM PROJECTION / RANDOM FOREST

# %%
#HIST DATA VARIABLES

# %%
X_train_agg = X_train.copy()
X_test_agg = X_test.copy()

# %%
pd.options.mode.chained_assignment = None
def calc_agg(df):
    for i in (1,2,3):
        sem1_var = [c for c in X_train.columns if ((c[:18] == 'price_p' + str(i) + '_var_2015-') & (c[-2:] in ['01','02','03','04','05','06']))]
        sem1_fix = [c for c in X_train.columns if ((c[:18] == 'price_p' + str(i) + '_fix_2015-') & (c[-2:] in ['01','02','03','04','05','06']))]
        sem2_var = [c for c in X_train.columns if ((c[:18] == 'price_p' + str(i) + '_var_2015-') & (c[-2:] in ['07','08','09','10','11','12']))]
        sem2_fix = [c for c in X_train.columns if ((c[:18] == 'price_p' + str(i) + '_fix_2015-') & (c[-2:] in ['07','08','09','10','11','12']))]
        df['price_p' + str(i) + '_var_sem1'] = df[sem1_var].mean(axis=1)
        df['price_p' + str(i) + '_var_sem2'] = df[sem2_var].mean(axis=1)
        df['price_p' + str(i) + '_fix_sem1'] = df[sem1_fix].mean(axis=1)
        df['price_p' + str(i) + '_fix_sem2'] = df[sem2_fix].mean(axis=1)
        df = df[[c for c in df.columns if c not in (sem1_var + sem2_var + sem1_fix + sem2_fix)]]
    return df

X_train_agg = calc_agg(X_train_agg)
X_test_agg = calc_agg(X_test_agg)

# %%
#X_train_agg.columns

# %%
X_train_agg = X_train_agg[[c for c in X_train_agg.columns if c[:7] not in ('channel','has_gas','origin_')]]
X_test_agg = X_test_agg[[c for c in X_test_agg.columns if c[:7] not in ('channel','has_gas','origin_')]]

# %%
#X_train_agg.columns

# %%
dftrain_objs_most.head()
dummies_all = pd.get_dummies(dftrain_objs_most,prefix=dftrain_objs_most.columns)
dummies_all.shape
# Out:
# (16096, 433)

# %%
from sklearn import random_projection
proj = random_projection.GaussianRandomProjection(n_components = 24)
dftrain_objs_most_proj = pd.DataFrame(proj.fit_transform(dummies_all),index=dummies_all.index)
dftrain_objs_most_proj.shape
# Out:
# (16096, 24)

# %%
dftrain_objs_most_proj.columns = ['dummy_' + str(c+1) for c in dftrain_objs_most_proj.columns]
dftrain_objs_most_proj.columns
# Out:
# Index(['dummy_1', 'dummy_2', 'dummy_3', 'dummy_4', 'dummy_5', 'dummy_6',
#        'dummy_7', 'dummy_8', 'dummy_9', 'dummy_10', 'dummy_11', 'dummy_12',
#        'dummy_13', 'dummy_14', 'dummy_15', 'dummy_16', 'dummy_17', 'dummy_18',
#        'dummy_19', 'dummy_20', 'dummy_21', 'dummy_22', 'dummy_23', 'dummy_24'],
#       dtype='object')

# %%
X_train_agg_proj = pd.merge(X_train_agg,dftrain_objs_most_proj,left_index=True,right_index=True,how='inner')
X_test_agg_proj = pd.merge(X_test_agg,dftrain_objs_most_proj,left_index=True,right_index=True,how='inner')

# %%
print(X_train.shape,X_train_agg_proj.shape,X_test.shape,X_test_agg_proj.shape,y_train.shape,y_test.shape)
# Out:
# (12876, 100) (12876, 50) (3220, 100) (3220, 50) (12876,) (3220,)

# %%
from sklearn.ensemble import RandomForestClassifier
randforest = RandomForestClassifier(random_state = 100)
randforest.fit(X_train_agg_proj, y_train)
print('Precision {:.2f}'.format(randforest.score(X_test_agg_proj, y_test)))
# Out:
# Precision 0.91

# %%
y_score=randforest.predict(X_test_agg_proj)
pd.crosstab(index=y_test,columns=y_score)
# Out:
# col_0     0   1
# churn
# 0      2887  14
# 1       287  32

# %%
print(classification_report(y_test, y_score, target_names=target_names))
# Out:
#              precision    recall  f1-score   support
#
#     class 0       0.91      1.00      0.95      2901
#     class 1       0.70      0.10      0.18       319
#
# avg / total       0.89      0.91      0.87      3220

# %%
y_proba = randforest.predict_proba(X_test_agg_proj)

# %%
dfallrows = allrows(y_test,y_proba,y_score)
df_results = pd.DataFrame([(0,.0,.0,.0)],columns=['n','threshold','precision','total'])
for i in range(1,dfallrows.shape[0]+1):
    dfn,threshold,precis,total = print_threshold_precision_total(dfallrows,i,0.20)
    df_results = df_results.append(pd.DataFrame([(i,threshold,precis,total)],columns=['n','threshold','precision','total']))
    if (total >= 50000) & (i >= 400):
        print(i,'Threshold {:.5f}'.format(threshold),'Precision: {0:0.2f}'.format(precis),'Total: {0:0.5f}'.format(total))
# Out:
# 400 Threshold 0.10000 Precision: 0.22 Total: 55187.28800
# 401 Threshold 0.10000 Precision: 0.22 Total: 57371.48800
# 402 Threshold 0.10000 Precision: 0.22 Total: 57144.22600
# 403 Threshold 0.10000 Precision: 0.22 Total: 62938.40200
# 404 Threshold 0.10000 Precision: 0.22 Total: 59933.54600
# 405 Threshold 0.10000 Precision: 0.22 Total: 59517.33400
# 406 Threshold 0.10000 Precision: 0.22 Total: 58935.76200
# 407 Threshold 0.10000 Precision: 0.22 Total: 58097.08400
# 408 Threshold 0.10000 Precision: 0.22 Total: 57886.27800
# 409 Threshold 0.10000 Precision: 0.22 Total: 57287.46200
# 410 Threshold 0.10000 Precision: 0.22 Total: 57113.86600
# 411 Threshold 0.10000 Precision: 0.22 Total: 56224.42600
# 412 Threshold 0.10000 Precision: 0.22 Total: 55740.66000
# 413 Threshold 0.10000 Precision: 0.22 Total: 55019.42200
# 414 Threshold 0.10000 Precision: 0.21 Total: 54856.38600
# 415 Threshold 0.10000 Precision: 0.21 Total: 51110.76000
# 416 Threshold 0.10000 Precision: 0.21 Total: 50312.38200
# 417 Threshold 0.10000 Precision: 0.21 Total: 50061.89600

# %%
df_results.head()
# Out:
#    n  threshold  precision     total
# 0  0        0.0        0.0     0.000
# 0  1        1.0        1.0   526.064
# 0  2        1.0        1.0  1205.528
# 0  3        1.0        1.0  1749.384
# 0  4        0.9        1.0  4640.664

# %%
df_results.plot.hexbin(x='n',y='threshold',C='total',color='orange',gridsize=100,figsize=(10,5))

# %%
#XGBOOST
